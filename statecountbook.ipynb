# %%
import gmaps
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint

googlekey = "AIzaSyDNjxDlnRd64VIsyxg2PRcdNw-r1vcSAF4"

nba = pd.read_csv("static/data/nba_cleaned.csv")
nba
# Out:
#      count                                       school  \
# 0       28                       University of Kentucky
# 1       24                              Duke University
# 2       14  University of North Carolina at Chapel Hill
# 3       13         University of California-Los Angeles
# 4       11            The University of Texas at Austin
# ..     ...                                          ...
# 129      1                          La Salle University
# 130      1          Southeast Missouri State University
# 131      1                       Boise State University
# 132      1                    College of the Holy Cross
# 133      0                                          NaN
#
#                                                address   latitude   longitude
# 0                   South Limestone Lexington KY 40506  38.038061  -84.507137
# 1                       103 Allen Bldg Durham NC 27708  36.001426  -78.938229
# ...

# %%
#Add Address column DF


#MAke empty list to hold names and address,city,statw, and zip
name = []
address = []
city = []
state = []
zipcode = []

#Open JSON file
f = open("static/data/Schools_Budget.json") 
  
#Return json file as dict
data = json.load(f) 
  

#iterate through json and pull necessary keys
for i  in data:
    name.append(i["institution_name"])
    address.append(i["addr1_txt"])
    city.append(i["city_txt"])
    state.append(i["state_cd"])
    zipcode.append(i["zip_text"])
   
        
    
    
    
# Closing file 
f.close() 
#add name and address list to DF  
latlongbook["Name"]= name
latlongbook["Address"]= address
latlongbook["City"]= city
latlongbook["State"]= state
latlongbook["Zip"]= zipcode

# %%
latlongbook
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4949ce90dec4> in <module>
# ----> 1 latlongbook
#
# NameError: name 'latlongbook' is not defined

# %%
#drop duplicate values
latlongbook1 = latlongbook.drop_duplicates()

latlongbook2 = latlongbook1.reset_index(drop = True)

# %%
merged = pd.merge(nba,latlongbook2,how = "left", on="Name")
merged
# Out:
#      count                                         Name  \
# 0       28                       University of Kentucky
# 1       24                              Duke University
# 2       14  University of North Carolina at Chapel Hill
# 3       13         University of California-Los Angeles
# 4       11            The University of Texas at Austin
# ..     ...                                          ...
# 129      1                          La Salle University
# 130      1          Southeast Missouri State University
# 131      1                       Boise State University
# 132      1                    College of the Holy Cross
# 133      0                                          NaN
#
#                                                address   latitude   longitude  \
# 0                   South Limestone Lexington KY 40506  38.038061  -84.507137
# 1                       103 Allen Bldg Durham NC 27708  36.001426  -78.938229
# ...

# %%
merged1 = merged.groupby(by =["State"]).sum()
merged1
# Out:
#        count    latitude    longitude          Zip
# State
# AL         4   65.800566  -173.039626      72336.0
# AR         4   70.795658  -186.517684     144905.0
# AZ        12   65.654668  -222.890958     171008.0
# CA        36  354.337557 -1198.707848     927059.0
# CO         4   40.003497  -105.267711      80309.0
# CT         6   83.119625  -145.172694      12789.0
# DC         3   77.808583  -154.119273      40109.0
# FL        18  140.877714  -409.869596     164844.0
# GA         6   67.728673  -167.768832      60934.0
# IA        10   83.688554  -185.182944     102253.0
# ID         1   43.609316  -116.210812      83725.0
# IL         3   81.986966  -175.857155     122424.0
# IN        19  283.485283  -604.174347     327466.0
# KS        16  115.863631  -289.124284     199811.0
# KY        37  149.853588  -345.048012     164970.0
# LA         9  123.111139  -365.981566     282696.0
# MA         6  126.915162  -214.065846       6192.0
# ...

# %%
mergeloc = merged.loc[merged["State"] == "KY", :]
mergeloc
# Out:
#      count                         Name  \
# 0       28       University of Kentucky
# 18       6     University of Louisville
# 68       2      Murray State University
# 112      1  Western Kentucky University
#
#                                               address   latitude  longitude  \
# 0                  South Limestone Lexington KY 40506  38.038061 -84.507137
# 18                  2301 S 3rd St Louisville KY 40292  38.215795 -85.761432
# 68                     218 Wells Hall Murray KY 42071  36.616384 -88.321498
# 112  1906 College Heights Blvd Bowling Green KY 42101  36.983347 -86.457945
#
#                        Address           City State      Zip
# 0              South Limestone      Lexington    KY  40506.0
# 18               2301 S 3rd St     Louisville    KY  40292.0
# 68              218 Wells Hall         Murray    KY  42071.0
# 112  1906 College Heights Blvd  Bowling Green    KY  42101.0

# %%
merged2 = merged1.sort_values(by = ["count"], ascending= False)
merged3 = merged2.reset_index()
merged4 = merged3[["State", "count"]]
merged4
# Out:
#    State  count
# 0     NC     50
# 1     KY     37
# 2     CA     36
# 3     TX     28
# 4     IN     19
# 5     FL     18
# 6     PA     17
# 7     MI     17
# 8     WA     16
# 9     KS     16
# 10    TN     16
# 11    VA     14
# 12    AZ     12
# 13    NY     10
# 14    IA     10
# 15    OR      9
# 16    OH      9
# 17    LA      9
# 18    NV      7
# 19    MA      6
# 20    OK      6
# 21    SC      6
# 22    GA      6
# 23    NE      6
# 24    CT      6
# 25    WI      6
# 26    MO      6
# 27    UT      4
# 28    AL      4
# 29    AR      4
# 30    MD      4
# 31    CO      4
# 32    IL      3
# 33    DC      3
# 34    NM      2
# 35    MS      2
# 36    WV      2
# 37    WY      2
# 38    RI      1
# 39    MN      1
# 40    ID      1

# %%
merged4.to_json("static/data/bballstatecount.json")

# %%
merged4.to_csv("bballstatecount.csv", index = False)

# %%
nfl = pd.read_csv("static/data/nfl_cleaned.csv")
nfl
# Out:
#      count                                               Name  \
# 0       52                          The University of Alabama
# 1       43                  Ohio State University-Main Campus
# 2       40  Louisiana State University and Agricultural & ...
# 3       37                              University of Florida
# 4       32                   University of Michigan-Ann Arbor
# ..     ...                                                ...
# 229      1                                Bucknell University
# 230      1                           Alabama State University
# 231      1                        University of North Alabama
# 232      1                      Prairie View A & M University
# 233      1                    University of Northern Colorado
#
#                                                address   latitude   longitude
# 0              739 University Blvd Tuscaloosa AL 35487  33.209609  -87.546648
# ...

# %%
merger = pd.merge(nfl,latlongbook2,how = "left", on="Name")
merger
# Out:
#      count                                               Name  \
# 0       52                          The University of Alabama
# 1       43                  Ohio State University-Main Campus
# 2       40  Louisiana State University and Agricultural & ...
# 3       37                              University of Florida
# 4       32                   University of Michigan-Ann Arbor
# ..     ...                                                ...
# 229      1                                Bucknell University
# 230      1                           Alabama State University
# 231      1                        University of North Alabama
# 232      1                      Prairie View A & M University
# 233      1                    University of Northern Colorado
#
#                                                address   latitude   longitude  \
# 0              739 University Blvd Tuscaloosa AL 35487  33.209609  -87.546648
# ...

# %%
merger1 = merger.groupby(by =["State"]).sum()
merger2 = merger1.sort_values(by = ["count"], ascending = False)
merger3 = merger2.reset_index()
merger4 = merger3[["State", "count"]]
merger4
# Out:
#    State  count
# 0     TX    132
# 1     FL    131
# 2     CA    108
# 3     AL     89
# 4     OH     78
# 5     PA     67
# 6     NC     65
# 7     MI     65
# 8     SC     63
# 9     LA     61
# 10    TN     55
# 11    WA     50
# 12    IN     50
# 13    GA     48
# 14    VA     47
# 15    MS     45
# 16    OK     44
# 17    UT     43
# 18    IA     35
# 19    KY     31
# 20    WI     28
# 21    OR     26
# 22    MA     26
# 23    IL     25
# 24    CO     22
# 25    NE     19
# 26    NY     19
# 27    ID     18
# 28    AR     18
# 29    WV     17
# 30    MO     17
# 31    MD     16
# 32    KS     16
# 33    WY     14
# 34    AZ     13
# 35    NJ     13
# 36    CT     10
# 37    MN     10
# 38    ND      7
# 39    DE      6
# 40    SD      5
# 41    NV      5
# 42    NM      3
# 43    HI      2
# 44    ME      1
# 45    MT      1

# %%
merger4.to_json("fballstatecount.json")

# %%
merger4.to_csv("fballstatecount.csv", index = False)

# %%
fball = pd.read_csv("static/data/fballstatecount.csv")

# %%
bball = pd.read_csv("static/data/bballstatecount.csv")

# %%
countmerged = pd.merge(fball,bball, how = "outer", on = "State")

# %%
countmerged1 = countmerged.rename(columns = {"State":"State", "count_x":"Football", "count_y":"Basketball"})
countmerged2 = countmerged1.fillna(0)
countmerged2
# Out:
#    State  Football  Basketball
# 0     TX     132.0        28.0
# 1     FL     131.0        18.0
# 2     CA     108.0        36.0
# 3     AL      89.0         4.0
# 4     OH      78.0         9.0
# 5     PA      67.0        17.0
# 6     NC      65.0        50.0
# 7     MI      65.0        17.0
# 8     SC      63.0         6.0
# 9     LA      61.0         9.0
# 10    TN      55.0        16.0
# 11    WA      50.0        16.0
# 12    IN      50.0        19.0
# 13    GA      48.0         6.0
# 14    VA      47.0        14.0
# 15    MS      45.0         2.0
# 16    OK      44.0         6.0
# 17    UT      43.0         4.0
# 18    IA      35.0        10.0
# 19    KY      31.0        37.0
# 20    WI      28.0         6.0
# 21    OR      26.0         9.0
# 22    MA      26.0         6.0
# 23    IL      25.0         3.0
# 24    CO      22.0         4.0
# 25    NE      19.0         6.0
# 26    NY      19.0        10.0
# 27    ID      18.0         1.0
# 28    AR      18.0         4.0
# ...

# %%
countmerged2.to_csv("static/data/mergedstatecount.csv", index = False)

# %%
countmerged2.to_json("static/data/mergedstatecount.json")
