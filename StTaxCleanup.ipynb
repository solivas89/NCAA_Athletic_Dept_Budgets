# %%
import pandas as pd
import numpy as np

# %%
excel_file = "Resources/data/StateTaxData.xlsx"
df = pd.read_excel(excel_file, header=[0,1])
df.head()
# Out:
#                                  Tax Description               Code  \
#                               Unnamed: 0_level_1 Unnamed: 1_level_1
# 0                                    Total Taxes                NaN
# 1                                 Property taxes                T01
# 2                 Sales and gross receipts taxes                NaN
# 3               General sales and gross receipts                T09
# 4       Selective sales and gross receipts taxes                NaN
#
#   U.S. Total (excludes Washington, D.C.)                            \
#                                  2020 Q2      2020 Q1      2019 Q2
# 0                            239003096.0  267819233.0  336729246.0
# 1                              4210038.0    4778311.0    4317671.0
# 2                                    NaN          NaN          NaN
# 3                             77381150.0   83556671.0   93583744.0
# 4                                    NaN          NaN          NaN
#
# ...
